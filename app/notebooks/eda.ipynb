# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from imblearn.over_sampling import RandomOverSampler

# %%
dataset_path = r"C:/Users/user/Desktop/data/sleepapi/app/data/Wearable_Tech_Sleep_Stress_Dataset.csv"

def get_dataframe(path: str = dataset_path) -> pd.DataFrame:
    df = pd.read_csv(path)
    return df

# %%
df = get_dataframe()
new_cols = []
for column in df.columns:
    new_cols.append(column.replace(' ', '_').lower())

df.columns = new_cols
df.drop(columns=['user_id'], inplace=True)

# %%
df
# Out:
#       age  gender physical_activity_level  diet_type   bmi  \
# 0      56  Female                     Low    Healthy  25.1
# 1      69    Male                     Low    Average  25.8
# 2      46    Male                     Low    Average  24.0
# 3      32  Female                  Medium    Healthy  25.5
# 4      60    Male                  Medium  Unhealthy   NaN
# ...   ...     ...                     ...        ...   ...
# 9995   55  Female                  Medium    Average  20.9
# 9996   51  Female                  Medium    Healthy  21.9
# 9997   57    Male                     Low    Average  32.9
# 9998   64  Female                     Low    Average  18.4
# 9999   32  Female                     Low    Average  20.0
#
#       caffeine_intake_mg  water_intake_liters  screen_time_hours  daily_steps  \
# 0                   99.0                  1.6                3.9         4731
# 1                  104.0                  2.2                3.9         4440
# 2                  188.0                  1.4                5.5         5023
# 3                  124.0                  3.1                9.8         6082
# 4                    0.0                  2.4                5.3         7285
# ...                  ...                  ...                ...          ...
# 9995               327.0                  1.7                5.7         8336
# 9996               210.0                  1.3                8.7        10170
# 9997               227.0                  2.8               14.0         1000
# 9998               222.0                  2.3                7.3         4206
# 9999               197.0                  1.6                8.7         2746
#
#       calories_burned  resting_heart_rate  daily_sleep_hours  \
# 0                1697                74.0                6.6
# 1                1377                70.0                8.0
# 2                1289                72.0                8.2
# 3                1683                69.0                7.4
# 4                1621                73.0                7.9
# ...               ...                 ...                ...
# 9995             1555                61.0                6.3
# 9996             1671                65.0                5.0
# 9997             1592                89.0                6.4
# 9998             1429                65.0                6.6
# 9999             1240                68.0                6.1
#
#       deep_sleep_hours  sleep_quality_score daily_stress_level
# 0                  1.5                  4.0                Low
# 1                  2.4                  5.3                Low
# 2                  1.9                  5.0             Medium
# 3                  2.5                  3.9                Low
# 4                  2.2                  5.2                Low
# ...                ...                  ...                ...
# 9995               1.9                  4.1                Low
# 9996               1.3                  3.3                Low
# 9997               1.7                  2.8               High
# 9998               2.2                  4.0             Medium
# 9999               1.4                  3.4             Medium
#
# [10000 rows x 15 columns]

# %%
df.isna().sum()
df.dropna(axis=0, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9198 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   age                      9198 non-null   int64
#  1   gender                   9198 non-null   object
#  2   physical_activity_level  9198 non-null   object
#  3   diet_type                9198 non-null   object
#  4   bmi                      9198 non-null   float64
#  5   caffeine_intake_mg       9198 non-null   float64
#  6   water_intake_liters      9198 non-null   float64
#  7   screen_time_hours        9198 non-null   float64
#  8   daily_steps              9198 non-null   int64
#  9   calories_burned          9198 non-null   int64
#  10  resting_heart_rate       9198 non-null   float64
#  11  daily_sleep_hours        9198 non-null   float64
#  12  deep_sleep_hours         9198 non-null   float64
#  13  sleep_quality_score      9198 non-null   float64
#  14  daily_stress_level       9198 non-null   object
# dtypes: float64(8), int64(3), object(4)
# memory usage: 1.1+ MB

# %%
df.to_csv('C:/Users/user/Desktop/data/sleepapi/app/data/reSS.csv', index=False)
