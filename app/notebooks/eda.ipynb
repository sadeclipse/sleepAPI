# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from imblearn.over_sampling import RandomOverSampler

# %%
dataset_path = r"C:/Users/user/Desktop/data/sleepapi/app/data/Wearable_Tech_Sleep_Stress_Dataset.csv"

def get_dataframe(path: str = dataset_path) -> pd.DataFrame:
    df = pd.read_csv(path)
    return df

# %%
df = get_dataframe()
new_cols = []
for column in df.columns:
    new_cols.append(column.replace(' ', '_').lower())

df.columns = new_cols

# %%
df.drop(columns=['user_id'], inplace=True)
df
# Out:
#       age  gender physical_activity_level  diet_type   bmi  \
# 0      56  Female                     Low    Healthy  25.1
# 1      69    Male                     Low    Average  25.8
# 2      46    Male                     Low    Average  24.0
# 3      32  Female                  Medium    Healthy  25.5
# 4      60    Male                  Medium  Unhealthy   NaN
# ...   ...     ...                     ...        ...   ...
# 9995   55  Female                  Medium    Average  20.9
# 9996   51  Female                  Medium    Healthy  21.9
# 9997   57    Male                     Low    Average  32.9
# 9998   64  Female                     Low    Average  18.4
# 9999   32  Female                     Low    Average  20.0
#
#       caffeine_intake_mg  water_intake_liters  screen_time_hours  daily_steps  \
# 0                   99.0                  1.6                3.9         4731
# 1                  104.0                  2.2                3.9         4440
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   age                      10000 non-null  int64
#  1   gender                   10000 non-null  object
#  2   physical_activity_level  10000 non-null  object
#  3   diet_type                10000 non-null  object
#  4   bmi                      9790 non-null   float64
#  5   caffeine_intake_mg       9794 non-null   float64
#  6   water_intake_liters      10000 non-null  float64
#  7   screen_time_hours        10000 non-null  float64
#  8   daily_steps              10000 non-null  int64
#  9   calories_burned          10000 non-null  int64
#  10  resting_heart_rate       9781 non-null   float64
#  11  daily_sleep_hours        9810 non-null   float64
#  12  deep_sleep_hours         10000 non-null  float64
#  13  sleep_quality_score      10000 non-null  float64
# ...

# %%
df.describe()
# Out:
#                 age          bmi  caffeine_intake_mg  water_intake_liters  \
# count  10000.000000  9790.000000         9794.000000         10000.000000
# mean      43.539400    25.087406          207.365224             2.502550
# std       14.911636     3.905276          137.681368             0.802058
# min       18.000000    17.500000            0.000000             0.500000
# 25%       31.000000    22.300000          100.000000             2.000000
# 50%       43.000000    25.100000          201.000000             2.500000
# 75%       56.000000    27.800000          303.000000             3.000000
# max       69.000000    38.000000          730.000000             5.000000
#
#        screen_time_hours   daily_steps  calories_burned  resting_heart_rate  \
# count       10000.000000  10000.000000     10000.000000         9781.000000
# mean            7.060990   7963.857000      1573.986300           66.944177
# ...

# %%
df.daily_stress_level.value_counts()
# Out:
# daily_stress_level
# Low       5789
# Medium    3786
# High       425
# Name: count, dtype: int64

# %%
df.to_csv('C:/Users/user/Desktop/data/sleepapi/app/data/reSS.csv', index=False)
